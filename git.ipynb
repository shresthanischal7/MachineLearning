# %%
# %cd "C:\Users\shres\MachileLearning"
# Out:
# C:\Users\shres\MachileLearning

# %%
# !git init
# Out:
# Initialized empty Git repository in C:/Users/shres/MachileLearning/.git/

# %%
# !where git
# Out:
# C:\Program Files\Git\cmd\git.exe

# %%
# !git config --global user.name 'shresthanischal7'
# !git config --global user.email '
